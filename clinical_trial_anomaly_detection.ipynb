# %% [markdown]
# # Machine Learning-Assisted Detection of Data Quality Anomalies
#
# ## Stage 1: Research Design
#
# This notebook will be expanded stage-by-stage. Results will only be reported after the code has been executed on the generated synthetic dataset.

# %% [markdown]
# ## Research question
#
# Can an unsupervised machine learning model complement conventional rule-based checks by identifying potentially problematic clinical-trial records that may not be detected by traditional data-quality rules?
